# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/10.0 MB 1.7 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/10.0 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/10.0 MB 1.3 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/10.0 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/10.0 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/10.0 MB 1.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/10.0 MB 1.5 MB/s eta 0:00:06
#    ------------ --------------------------- 3.1/10.0 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 3.7/10.0 MB 1.7 MB/s eta 0:00:04
# ...

# %%
import pandas as pd

# %%
movies = pd.read_csv("../data/raw/IMDB-Movie-Dataset(2023-1951).csv")

movies.head()
# Out:
#    Unnamed: 0    movie_id                       movie_name  year  \
# 0           0  tt15354916                            Jawan  2023
# 1           1  tt15748830                       Jaane Jaan  2023
# 2           2  tt11663228                           Jailer  2023
# 3           3  tt14993250  Rocky Aur Rani Kii Prem Kahaani  2023
# 4           4  tt15732324                            OMG 2  2023
#
#                    genre                                           overview  \
# 0       Action, Thriller  A high-octane action thriller which outlines t...
# 1  Crime, Drama, Mystery  A single mother and her daughter who commit a ...
# 2  Action, Comedy, Crime  A retired jailer goes on a manhunt to find his...
# 3  Comedy, Drama, Family  Flamboyant Punjabi Rocky and intellectual Beng...
# 4          Comedy, Drama  An unhappy civilian asks the court to mandate ...
#
#             director                                               cast
# ...

# %%
movies.shape
# Out:
# (2199, 8)

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'movie_id', 'movie_name', 'year', 'genre', 'overview',
#        'director', 'cast'],
#       dtype='str')

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2199 non-null   int64
#  1   movie_id    2199 non-null   str
#  2   movie_name  2199 non-null   str
#  3   year        2134 non-null   str
#  4   genre       2199 non-null   str
#  5   overview    2199 non-null   str
#  6   director    2199 non-null   str
#  7   cast        2199 non-null   str
# dtypes: int64(1), str(7)
# memory usage: 137.6 KB

# %%
movies.describe()
# Out:
#         Unnamed: 0
# count  2199.000000
# mean   1099.369259
# std     635.344495
# min       0.000000
# 25%     549.500000
# 50%    1099.000000
# 75%    1649.500000
# max    2199.000000
