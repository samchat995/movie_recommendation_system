# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in C:\Users\SAMIRAN\AppData\Roaming\Python\Python314\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\SAMIRAN\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\SAMIRAN\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\SAMIRAN\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\SAMIRAN\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
movies = pd.read_csv("../data/processed/imdb_preprocessed.csv")

movies.head()
# Out:
#                         movie_name  year                genre  \
# 0                            jawan  2023      action thriller
# 1                       jaane jaan  2023  crime drama mystery
# 2                           jailer  2023  action comedy crime
# 3  rocky aur rani kii prem kahaani  2023  comedy drama family
# 4                            omg 2  2023         comedy drama
#
#                                                 tags
# 0  action thriller highoctan action thriller outl...
# 1  crime drama mysteri singl mother daughter comm...
# 2  action comedi crime retir jailer goe manhunt f...
# 3  comedi drama famili flamboy punjabi rocki inte...
# 4  comedi drama unhappi civilian ask court mandat...

# %%
movies.shape
# Out:
# (2199, 4)

# %%
movies["tags"].head()
# Out:
# 0    action thriller highoctan action thriller outl...
# 1    crime drama mysteri singl mother daughter comm...
# 2    action comedi crime retir jailer goe manhunt f...
# 3    comedi drama famili flamboy punjabi rocki inte...
# 4    comedi drama unhappi civilian ask court mandat...
# Name: tags, dtype: object

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    stop_words="english",
    token_pattern=r'(?u)\b[a-zA-Z]{2,}\b'
)

# %%
tfidf_matrix = tfidf.fit_transform(movies["tags"])

# %%
tfidf_matrix.shape
# Out:
# (2199, 5000)

# %%
feature_names = tfidf.get_feature_names_out()

feature_names[:20]
# Out:
# array(['aadarsh', 'aadukalam', 'aahana', 'aakanksha', 'aakash', 'aakeel',
#        'aakkash', 'aakriti', 'aakshath', 'aalaap', 'aaliya', 'aamir',
#        'aanand', 'aanande', 'aanchal', 'aankhen', 'aarav', 'aarden',
#        'aarti', 'aaryaan'], dtype=object)

# %%
import pickle

with open("../models/tfidf_vectorizer.pkl", "wb") as file:
    pickle.dump(tfidf, file)

# %%
with open("../models/tfidf_matrix.pkl", "wb") as f:
    pickle.dump(tfidf_matrix, f)
